# %% [markdown]
# ---
#
# ## Predictive modeling of customer bookings
#
# This Jupyter notebook includes some code to get you started with this predictive modeling task. We will use various packages for data manipulation, feature engineering and machine learning.
#
# ### Exploratory data analysis
#
# First, we must explore the data in order to better understand what we have and the statistical properties of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/customer_booking.csv", encoding="ISO-8859-1")
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             5.52
# 1                     0                      0             5.52
# 2                     1                      0             5.52
# 3                     0                      1             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# The `.head()` method allows us to view the first 5 rows in the dataset, this is useful for visual inspection of our columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50000 non-null  int64
#  1   sales_channel          50000 non-null  object
#  2   trip_type              50000 non-null  object
#  3   purchase_lead          50000 non-null  int64
#  4   length_of_stay         50000 non-null  int64
#  5   flight_hour            50000 non-null  int64
#  6   flight_day             50000 non-null  object
#  7   route                  50000 non-null  object
#  8   booking_origin         50000 non-null  object
#  9   wants_extra_baggage    50000 non-null  int64
#  10  wants_preferred_seat   50000 non-null  int64
#  11  wants_in_flight_meals  50000 non-null  int64
#  12  flight_duration        50000 non-null  float64
#  13  booking_complete       50000 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.3+ MB

# %% [markdown]
# The `.info()` method gives us a data description, telling us the names of the columns, their data types and how many null values we have. Fortunately, we have no null values. It looks like some of these columns should be converted into different data types, e.g. flight_day.
#
# To provide more context, below is a more detailed data description, explaining exactly what each column means:
#
# - `num_passengers` = number of passengers travelling
# - `sales_channel` = sales channel booking was made on
# - `trip_type` = trip Type (Round Trip, One Way, Circle Trip)
# - `purchase_lead` = number of days between travel date and booking date
# - `length_of_stay` = number of days spent at destination
# - `flight_hour` = hour of flight departure
# - `flight_day` = day of week of flight departure
# - `route` = origin -> destination flight route
# - `booking_origin` = country from where booking was made
# - `wants_extra_baggage` = if the customer wanted extra baggage in the booking
# - `wants_preferred_seat` = if the customer wanted a preferred seat in the booking
# - `wants_in_flight_meals` = if the customer wanted in-flight meals in the booking
# - `flight_duration` = total duration of flight (in hours)
# - `booking_complete` = flag indicating if the customer completed the booking
#
# Before we compute any statistics on the data, lets do any necessary data conversion

# %%
df["flight_day"].unique()
# Out:
# array(['Sat', 'Wed', 'Thu', 'Mon', 'Sun', 'Tue', 'Fri'], dtype=object)

# %%
mapping = {
    "Mon": 1,
    "Tue": 2,
    "Wed": 3,
    "Thu": 4,
    "Fri": 5,
    "Sat": 6,
    "Sun": 7,
}

df["flight_day"] = df["flight_day"].map(mapping)

# %%
df["flight_day"].unique()
# Out:
# array([6, 3, 4, 1, 7, 2, 5])

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count    50000.000000   50000.000000     50000.00000  50000.00000
# mean         1.591240      84.940480        23.04456      9.06634
# std          1.020165      90.451378        33.88767      5.41266
# min          1.000000       0.000000         0.00000      0.00000
# 25%          1.000000      21.000000         5.00000      5.00000
# 50%          1.000000      51.000000        17.00000      9.00000
# 75%          2.000000     115.000000        28.00000     13.00000
# max          9.000000     867.000000       778.00000     23.00000
#
#          flight_day  wants_extra_baggage  wants_preferred_seat  \
# count  50000.000000         50000.000000          50000.000000
# mean       3.814420             0.668780              0.296960
# std        1.992792             0.470657              0.456923
# min        1.000000             0.000000              0.000000
# 25%        2.000000             0.000000              0.000000
# 50%        4.000000             1.000000              0.000000
# 75%        5.000000             1.000000              1.000000
# max        7.000000             1.000000              1.000000
#
#        wants_in_flight_meals  flight_duration  booking_complete
# count           50000.000000     50000.000000      50000.000000
# mean                0.427140         7.277561          0.149560
# std                 0.494668         1.496863          0.356643
# min                 0.000000         4.670000          0.000000
# 25%                 0.000000         5.620000          0.000000
# 50%                 0.000000         7.570000          0.000000
# 75%                 1.000000         8.830000          0.000000
# max                 1.000000         9.500000          1.000000

# %%
df.shape
# Out:
# (50000, 14)

# %%
df.columns
# Out:
# Index(['num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
#        'length_of_stay', 'flight_hour', 'flight_day', 'route',
#        'booking_origin', 'wants_extra_baggage', 'wants_preferred_seat',
#        'wants_in_flight_meals', 'flight_duration', 'booking_complete'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# num_passengers           0
# sales_channel            0
# trip_type                0
# purchase_lead            0
# length_of_stay           0
# flight_hour              0
# flight_day               0
# route                    0
# booking_origin           0
# wants_extra_baggage      0
# wants_preferred_seat     0
# wants_in_flight_meals    0
# flight_duration          0
# booking_complete         0
# dtype: int64

# %% [markdown]
# The `.describe()` method gives us a summary of descriptive statistics over the entire dataset (only works for numeric columns). This gives us a quick overview of a few things such as the mean, min, max and overall distribution of each column.
#
# From this point, you should continue exploring the dataset with some visualisations and other metrics that you think may be useful. Then, you should prepare your dataset for predictive modelling. Finally, you should train your machine learning model, evaluate it with performance metrics and output visualisations for the contributing variables. All of this analysis should be summarised in your single slide.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(1)
# Out:
# <ipython-input-33-7d17148e0c02>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(1)
# <style type="text/css">
# #T_575c7_row0_col0, #T_575c7_row1_col1, #T_575c7_row2_col2, #T_575c7_row3_col3, #T_575c7_row4_col4, #T_575c7_row5_col5, #T_575c7_row6_col6, #T_575c7_row7_col7, #T_575c7_row8_col8, #T_575c7_row9_col9, #T_575c7_row10_col10, #T_575c7_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col2, #T_575c7_row6_col2, #T_575c7_row10_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_575c7_row0_col4, #T_575c7_row1_col7, #T_575c7_row1_col9, #T_575c7_row2_col8, #T_575c7_row3_col8, #T_575c7_row3_col9, #T_575c7_row4_col0, #T_575c7_row4_col1, #T_575c7_row4_col3, #T_575c7_row4_col5, #T_575c7_row10_col11, #T_575c7_row11_col2, #T_575c7_row11_col6, #T_575c7_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col5, #T_575c7_row1_col8, #T_575c7_row4_col8, #T_575c7_row5_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col6, #T_575c7_row5_col8, #T_575c7_row10_col1, #T_575c7_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col8, #T_575c7_row0_col10, #T_575c7_row2_col1, #T_575c7_row3_col4, #T_575c7_row7_col2, #T_575c7_row8_col5, #T_575c7_row9_col1, #T_575c7_row9_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col9, #T_575c7_row1_col5, #T_575c7_row3_col1, #T_575c7_row3_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_575c7_row0_col11, #T_575c7_row4_col9, #T_575c7_row5_col0, #T_575c7_row6_col0, #T_575c7_row9_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_575c7_row1_col0, #T_575c7_row2_col0, #T_575c7_row5_col3, #T_575c7_row5_col11, #T_575c7_row6_col3, #T_575c7_row6_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_575c7_row1_col2, #T_575c7_row2_col6, #T_575c7_row2_col9, #T_575c7_row4_col6, #T_575c7_row7_col1, #T_575c7_row7_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_575c7_row1_col3, #T_575c7_row1_col10, #T_575c7_row1_col11, #T_575c7_row2_col7, #T_575c7_row3_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_575c7_row1_col4, #T_575c7_row1_col6, #T_575c7_row6_col5, #T_575c7_row6_col7, #T_575c7_row7_col3, #T_575c7_row9_col3, #T_575c7_row10_col0, #T_575c7_row11_col3, #T_575c7_row11_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_575c7_row2_col3, #T_575c7_row5_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_575c7_row2_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_575c7_row2_col5, #T_575c7_row3_col7, #T_575c7_row5_col2, #T_575c7_row5_col6, #T_575c7_row6_col9, #T_575c7_row11_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_575c7_row2_col10, #T_575c7_row10_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_575c7_row2_col11 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_575c7_row3_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_575c7_row3_col2, #T_575c7_row5_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_575c7_row3_col10, #T_575c7_row7_col11 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_575c7_row3_col11, #T_575c7_row5_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_575c7_row4_col2, #T_575c7_row6_col8, #T_575c7_row7_col5, #T_575c7_row8_col6, #T_575c7_row9_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_575c7_row4_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_575c7_row4_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_575c7_row4_col11, #T_575c7_row11_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_575c7_row5_col10, #T_575c7_row6_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_575c7_row6_col10 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_575c7_row6_col11, #T_575c7_row8_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_575c7_row7_col0, #T_575c7_row7_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_575c7_row7_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_575c7_row7_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_575c7_row7_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_575c7_row8_col0, #T_575c7_row8_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_575c7_row8_col2, #T_575c7_row9_col6, #T_575c7_row11_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_575c7_row8_col3, #T_575c7_row10_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_575c7_row8_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_575c7_row8_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_575c7_row8_col10 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_575c7_row8_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_575c7_row9_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_575c7_row9_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_575c7_row9_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_575c7_row9_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_575c7_row9_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_575c7_row10_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_575c7_row10_col7, #T_575c7_row10_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_575c7_row10_col9 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_575c7_row11_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_575c7_row11_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_575c7_row11_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_575c7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_passengers</th>
#       <th class="col_heading level0 col1" >sales_channel</th>
#       <th class="col_heading level0 col2" >trip_type</th>
#       <th class="col_heading level0 col3" >purchase_lead</th>
#       <th class="col_heading level0 col4" >length_of_stay</th>
#       <th class="col_heading level0 col5" >flight_hour</th>
#       <th class="col_heading level0 col6" >flight_day</th>
#       <th class="col_heading level0 col7" >wants_extra_baggage</th>
#       <th class="col_heading level0 col8" >wants_preferred_seat</th>
#       <th class="col_heading level0 col9" >wants_in_flight_meals</th>
#       <th class="col_heading level0 col10" >flight_duration</th>
#       <th class="col_heading level0 col11" >booking_complete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_575c7_level0_row0" class="row_heading level0 row0" >num_passengers</th>
#       <td id="T_575c7_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_575c7_row0_col1" class="data row0 col1" >-0.0</td>
#       <td id="T_575c7_row0_col2" class="data row0 col2" >-0.0</td>
#       <td id="T_575c7_row0_col3" class="data row0 col3" >0.2</td>
#       <td id="T_575c7_row0_col4" class="data row0 col4" >-0.1</td>
#       <td id="T_575c7_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_575c7_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_575c7_row0_col7" class="data row0 col7" >0.1</td>
#       <td id="T_575c7_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_575c7_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_575c7_row0_col10" class="data row0 col10" >-0.1</td>
#       <td id="T_575c7_row0_col11" class="data row0 col11" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_575c7_level0_row1" class="row_heading level0 row1" >sales_channel</th>
#       <td id="T_575c7_row1_col0" class="data row1 col0" >-0.0</td>
#       <td id="T_575c7_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_575c7_row1_col2" class="data row1 col2" >-0.0</td>
#       <td id="T_575c7_row1_col3" class="data row1 col3" >-0.0</td>
#       <td id="T_575c7_row1_col4" class="data row1 col4" >-0.1</td>
#       <td id="T_575c7_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_575c7_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_575c7

# %%
ax = sns.heatmap(corr,vmin=1,vmax=1,center=0,
  cmap=sns.diverging_palette(20,220,n=200),
  square=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
# Out:
# 49995    0
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: booking_complete, dtype: int64

# %%
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour  flight_day  wants_extra_baggage  wants_preferred_seat  \
# 0            7           6                    1                     0
# 1            3           6                    0                     0
# 2           17           3                    1                     1
# 3            4           6                    0                     0
# 4           15           3                    1                     0
#
#    wants_in_flight_meals  flight_duration
# 0                      0             5.52
# 1                      0             5.52
# 2                      0             5.52
# 3                      1             5.52
# 4                      1             5.52

# %%
df['sales_channel'].unique()
# Out:
# array(['Internet', 'Mobile'], dtype=object)

# %%
mapping = {
    "Internet": 1,
    "Mobile": 2,
   }
df["sales_channel"] = df["sales_channel"].map(mapping)

# %%
df['trip_type'].unique()
# Out:
# array(['RoundTrip', 'CircleTrip', 'OneWay'], dtype=object)

# %%
mapping = {
    "RoundTrip": 1,
    "CircleTrip": 2,
    "OneWay": 3,
}

df["trip_type"] = df["trip_type"].map(mapping)

# %%
df.head()
# Out:
#    num_passengers  sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2              1          1            262              19
# 1               1              1          1            112              20
# 2               2              1          1            243              22
# 3               1              1          1             96              31
# 4               2              1          1             68              22
#
#    flight_hour  flight_day   route booking_origin  wants_extra_baggage  \
# 0            7           6  AKLDEL    New Zealand                    1
# 1            3           6  AKLDEL    New Zealand                    0
# 2           17           3  AKLDEL          India                    1
# 3            4           6  AKLDEL    New Zealand                    0
# 4           15           3  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             5.52
# 1                     0                      0             5.52
# 2                     1                      0             5.52
# 3                     0                      1             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
booking=df['booking_complete']
booking.tail()
# Out:
# 49995    0
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: booking_complete, dtype: int64

# %%
data=df.drop(['booking_complete','route','booking_origin'],axis=1)
data.head()
# Out:
#    num_passengers  sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2              1          1            262              19
# 1               1              1          1            112              20
# 2               2              1          1            243              22
# 3               1              1          1             96              31
# 4               2              1          1             68              22
#
#    flight_hour  flight_day  wants_extra_baggage  wants_preferred_seat  \
# 0            7           6                    1                     0
# 1            3           6                    0                     0
# 2           17           3                    1                     1
# 3            4           6                    0                     0
# 4           15           3                    1                     0
#
#    wants_in_flight_meals  flight_duration
# 0                      0             5.52
# 1                      0             5.52
# 2                      0             5.52
# 3                      1             5.52
# 4                      1             5.52

# %%
x_train , x_test , y_train , y_test = train_test_split(data , booking , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.014039155078534038

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# GradientBoostingRegressor(loss='ls', max_depth=5, n_estimators=400)

# %%
clf.score(x_test,y_test)
# Out:
# 0.035973743634216016
